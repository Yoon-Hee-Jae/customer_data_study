# %%
import pandas as pd

# %%
df = pd.read_excel('/content/매출데이터(SuperStore).xls')
df
# Out:
#             주문일  배송방식               고객명  고객분류 시군구(City) 도(State)   지역 제품대분류  \
# 0    2014-11-09   2등급       Claire Gute  개인고객       천안시     충청남도   충청    가구
# 1    2014-11-09   2등급       Claire Gute  개인고객       천안시     충청남도   충청    가구
# 2    2014-06-13   2등급   Darrin Van Huff  기업고객       송파구       서울  수도권  사무용품
# 3    2013-10-11  표준등급    Sean O'Donnell  개인고객       영광군     전라남도   전라    가구
# 4    2013-10-11  표준등급    Sean O'Donnell  개인고객       영광군     전라남도   전라  사무용품
# ...         ...   ...               ...   ...       ...      ...  ...   ...
# 8188 2012-01-22   2등급  Tom Boeckenhauer  개인고객       순천시     전라남도   전라    가구
# 8189 2015-02-27  표준등급       Dave Brooks  개인고객       종로구       서울  수도권    가구
# 8190 2015-02-27  표준등급       Dave Brooks  개인고객       종로구       서울  수도권  전자제품
# 8191 2015-02-27  표준등급       Dave Brooks  개인고객       종로구       서울  수도권  사무용품
# 8192 2015-05-05   2등급      Chris Cortes  개인고객       광진구       서울  수도권  사무용품
#
# ...

# %%
df['고객명'].nunique()
# Out:
# 791

# %%
df['고객분류'].value_counts()
# Out:
# 개인고객    4300
# 기업고객    2459
# 홈오피스    1434
# Name: 고객분류, dtype: int64

# %%
df['제품대분류'].value_counts()
# Out:
# 사무용품    4905
# 가구      1754
# 전자제품    1534
# Name: 제품대분류, dtype: int64

# %%
df[df['제품대분류']=='사무용품'].describe()
# Out:
#                 매출           수량          할인율           이익
# count  4905.000000  4905.000000  4905.000000  4905.000000
# mean    115.664256     3.792864     0.172110    17.572758
# std     370.698183     2.226085     0.236281   161.283328
# min       0.444000     1.000000     0.000000 -3701.892800
# 25%      11.520000     2.000000     0.000000     1.814400
# 50%      26.720000     3.000000     0.200000     6.420000
# 75%      77.550000     5.000000     0.200000    18.396000
# max    9892.740000    14.000000     0.800000  4946.370000

# %%
df['제품소분류'].value_counts()
# Out:
# 바인더         1237
# 종이          1098
# 기타 가구        786
# 전화기          741
# 저장고          688
# 아트           646
# 액세서리         634
# 의자           522
# 가정용 전자기기     386
# 라벨           301
# 테이블          260
# 봉투           212
# 책장           186
# 잠금장치         181
# 소모품          156
# 기계           102
# 복사기           57
# Name: 제품소분류, dtype: int64

# %%
df[df['제품소분류']=='바인더']
# Out:
#             주문일  배송방식                 고객명  고객분류 시군구(City) 도(State)   지역 제품대분류  \
# 8    2012-06-09  표준등급     Brosina Hoffman  개인고객       송파구       서울  수도권  사무용품
# 13   2014-12-06  표준등급        Irene Maddox  개인고객        중구       서울  수도권  사무용품
# 15   2013-11-22  표준등급       Harold Pawlan  홈오피스       광명시      경기도  수도권  사무용품
# 19   2012-08-27   2등급  Zuschuss Donatelli  개인고객       서초구       서울  수도권  사무용품
# 21   2014-01-16   2등급       Eric Hoffmann  개인고객       송파구       서울  수도권  사무용품
# ...         ...   ...                 ...   ...       ...      ...  ...   ...
# 8167 2015-12-12  표준등급     Richard Bierner  개인고객       제천시     충청북도   충청  사무용품
# 8168 2015-12-12  표준등급     Richard Bierner  개인고객       제천시     충청북도   충청  사무용품
# 8170 2013-06-28  표준등급         Mark Packer  홈오피스       속초시      강원도   강원  사무용품
# 8178 2014-12-07  표준등급          Anne Pryor  홈오피스       송파구       서울  수도권  사무용품
# 8179 2014-12-07  표준등급          Anne Pryor  홈오피스       송파구       서울  수도권  사무용품
#
# ...

# %%
df['이름'].value_counts()
# Out:
# Staple envelope                                                      39
# Easy-staple paper                                                    36
# Staples                                                              36
# Staples in misc. colors                                              16
# Staple remover                                                       15
#                                                                      ..
# Classic Ivory Antique Telephone ZL1810                                1
# Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection     1
# Ibico EPK-21 Electric Binding System                                  1
# Boston 1900 Electric Pencil Sharpener                                 1
# Boston Model 1800 Electric Pencil Sharpener, Gray                     1
# Name: 이름, Length: 1827, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# seaborn을 사용하여 히스토그램과 KDE를 함께 시각화
plt.figure(figsize=(10, 6))
sns.histplot(df['매출'], kde=True, color='blue')
plt.title('매출 분포')
plt.xlabel('매출')
plt.ylabel('빈도')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sorted_df = df.sort_values(by=['고객명','주문일']).reset_index()
sorted_df.head(30)
# Out:
#     index        주문일  배송방식              고객명  고객분류 시군구(City) 도(State)     지역  \
# 0    6689 2012-02-19  표준등급    Aaron Bergman  개인고객       수원시      경기도    수도권
# 1    4074 2012-03-07   1등급    Aaron Bergman  개인고객        중구       서울    수도권
# 2    4075 2012-03-07   1등급    Aaron Bergman  개인고객        중구       서울    수도권
# 3    4076 2012-03-07   1등급    Aaron Bergman  개인고객        중구       서울    수도권
# 4    5858 2012-04-22   2등급    Aaron Hawkins  기업고객      남양주시      경기도    수도권
# 5    5859 2012-04-22   2등급    Aaron Hawkins  기업고객      남양주시      경기도    수도권
# 6    4387 2012-05-13  표준등급    Aaron Hawkins  기업고객       송파구       서울    수도권
# 7    4388 2012-05-13  표준등급    Aaron Hawkins  기업고객       송파구       서울    수도권
# 8    5008 2012-10-25   1등급    Aaron Hawkins  기업고객       서초구       서울    수도권
# 9    7159 2012-12-31   1등급    Aaron Hawkins  기업고객       성남시      경기도    수도권
# 10   7160 2012-12-31   1등급    Aaron Hawkins  기업고객       성남시      경기도    수도권
# ...

# %%
sales_df = df.groupby('고객명')[['매출','수량','이익']].mean().sort_values(by='이익',ascending=False).reset_index()
sales_df.head(30)
# Out:
#                      고객명           매출        수량          이익
# 0           Tamara Chand  1853.029800  3.300000  878.534310
# 1           Tom Ashbrook  2301.295000  4.000000  753.893750
# 2       Mitch Willingham  1751.292000  4.333333  555.172000
# 3           Raymond Buch  1074.044571  4.000000  497.168064
# 4   Christopher Martinez   964.947778  3.444444  432.722289
# 5            Andy Reiter   934.364000  4.000000  408.210600
# 6           Bill Shonely  1491.009000  5.000000  370.265643
# 7          Ionia McGrath   944.183333  4.333333  318.843900
# 8          Adrian Barton   743.624579  3.736842  284.527700
# 9          Robert Marley   826.959333  3.500000  269.726200
# 10             Jane Waco   928.799250  5.250000  260.131950
# 11          Nathan Mautz   572.325818  3.363636  243.449064
# 12      Tom Boeckenhauer   674.483333  3.166667  208.864683
# 13       George Zrebassa   602.090500  5.500000  204.042700
# 14          Fred Hopkins   596.386727  4.181818  202.066918
# ...

# %%
first_order_dates = df.groupby('고객명')['주문일'].min().reset_index()
first_order_dates
# Out:
#                     고객명        주문일
# 0         Aaron Bergman 2012-02-19
# 1         Aaron Hawkins 2012-04-22
# 2        Aaron Smayling 2012-07-27
# 3       Adam Bellavance 2013-09-18
# 4             Adam Hart 2012-11-16
# ..                  ...        ...
# 786        Xylona Preis 2012-01-21
# 787       Yana Sorensen 2013-12-08
# 788      Yoseph Carroll 2013-11-12
# 789    Zuschuss Carroll 2012-10-13
# 790  Zuschuss Donatelli 2012-08-27
#
# [791 rows x 2 columns]

# %%
import pandas as pd
from pandas import Series
from pandas import DataFrame

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('/content/매출데이터(SuperStore).xls')
new_df = df[df['제품소분류']=='바인더'].reset_index(drop=True)
new_df
# Out:
#             주문일  배송방식                 고객명  고객분류 시군구(City) 도(State)   지역 제품대분류  \
# 0    2012-06-09  표준등급     Brosina Hoffman  개인고객       송파구       서울  수도권  사무용품
# 1    2014-12-06  표준등급        Irene Maddox  개인고객        중구       서울  수도권  사무용품
# 2    2013-11-22  표준등급       Harold Pawlan  홈오피스       광명시      경기도  수도권  사무용품
# 3    2012-08-27   2등급  Zuschuss Donatelli  개인고객       서초구       서울  수도권  사무용품
# 4    2014-01-16   2등급       Eric Hoffmann  개인고객       송파구       서울  수도권  사무용품
# ...         ...   ...                 ...   ...       ...      ...  ...   ...
# 1232 2015-12-12  표준등급     Richard Bierner  개인고객       제천시     충청북도   충청  사무용품
# 1233 2015-12-12  표준등급     Richard Bierner  개인고객       제천시     충청북도   충청  사무용품
# 1234 2013-06-28  표준등급         Mark Packer  홈오피스       속초시      강원도   강원  사무용품
# 1235 2014-12-07  표준등급          Anne Pryor  홈오피스       송파구       서울  수도권  사무용품
# 1236 2014-12-07  표준등급          Anne Pryor  홈오피스       송파구       서울  수도권  사무용품
#
# ...

# %%
type(new_df['주문일'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df = new_df.drop(['배송방식','고객분류','시군구(City)','도(State)','지역'],axis=1)
new_df
# Out:
#             주문일                 고객명 제품대분류 제품소분류  \
# 0    2012-06-09     Brosina Hoffman  사무용품   바인더
# 1    2014-12-06        Irene Maddox  사무용품   바인더
# 2    2013-11-22       Harold Pawlan  사무용품   바인더
# 3    2012-08-27  Zuschuss Donatelli  사무용품   바인더
# 4    2014-01-16       Eric Hoffmann  사무용품   바인더
# ...         ...                 ...   ...   ...
# 1232 2015-12-12     Richard Bierner  사무용품   바인더
# 1233 2015-12-12     Richard Bierner  사무용품   바인더
# 1234 2013-06-28         Mark Packer  사무용품   바인더
# 1235 2014-12-07          Anne Pryor  사무용품   바인더
# 1236 2014-12-07          Anne Pryor  사무용품   바인더
#
#                                                      이름       매출  수량  할인율  \
# 0     DXL Angle-View Binders with Locking Rings by S...   18.504   3  0.2
# 1           Fellowes PB200 Plastic Comb Binding Machine  407.976   3  0.2
# 2      Storex DuraTech Recycled Plastic Frosted Binders    2.544   3  0.8
# 3           Wilson Jones Hanging View Binder, White, 1"   22.720   4  0.2
# ...

# %%
new_df['OrderCycle'] = new_df['주문일'].dt.strftime('%Y.%m')
new_df.head()
# Out:
#          주문일                 고객명 제품대분류 제품소분류  \
# 0 2012-06-09     Brosina Hoffman  사무용품   바인더
# 1 2014-12-06        Irene Maddox  사무용품   바인더
# 2 2013-11-22       Harold Pawlan  사무용품   바인더
# 3 2012-08-27  Zuschuss Donatelli  사무용품   바인더
# 4 2014-01-16       Eric Hoffmann  사무용품   바인더
#
#                                                   이름       매출  수량  할인율  \
# 0  DXL Angle-View Binders with Locking Rings by S...   18.504   3  0.2
# 1        Fellowes PB200 Plastic Comb Binding Machine  407.976   3  0.2
# 2   Storex DuraTech Recycled Plastic Frosted Binders    2.544   3  0.8
# 3        Wilson Jones Hanging View Binder, White, 1"   22.720   4  0.2
# 4                    Wilson Jones Active Use Binders   11.648   2  0.2
#
#          이익 OrderCycle
# 0    5.7825    2012.06
# 1  132.5922    2014.12
# 2   -3.8160    2013.11
# 3    7.3840    2012.08
# 4    4.2224    2014.01

# %%
## Group by를 통한 최고 구매일 계산
first_order = new_df.groupby('이름')['주문일'].min()
first_order = first_order.dt.strftime('%Y.%m')
first_order.head()
# Out:
# 이름
# 3-ring staple pack                  2013.06
# 3M Organizer Strips                 2012.11
# ACCOHIDE 3-Ring Binder, Blue, 1"    2012.04
# ACCOHIDE Binder by Acco             2012.04
# Acco 3-Hole Punch                   2012.09
# Name: 주문일, dtype: object

# %%
## Data Frame의 Index를 User Id로 일시적으로 전환
new_df = new_df.set_index('이름')

## 데이터 First 데이터는 Series + DF는 pandas이기에 Index 기준 자동 병합가능
new_df['FirstOrder'] = first_order

## Index의 정상화
new_df.reset_index(inplace = True)

new_df.head()
# Out:
#                                                   이름        주문일  \
# 0  DXL Angle-View Binders with Locking Rings by S... 2012-06-09
# 1        Fellowes PB200 Plastic Comb Binding Machine 2014-12-06
# 2   Storex DuraTech Recycled Plastic Frosted Binders 2013-11-22
# 3        Wilson Jones Hanging View Binder, White, 1" 2012-08-27
# 4                    Wilson Jones Active Use Binders 2014-01-16
#
#                   고객명 제품대분류 제품소분류       매출  수량  할인율        이익 OrderCycle  \
# 0     Brosina Hoffman  사무용품   바인더   18.504   3  0.2    5.7825    2012.06
# 1        Irene Maddox  사무용품   바인더  407.976   3  0.2  132.5922    2014.12
# 2       Harold Pawlan  사무용품   바인더    2.544   3  0.8   -3.8160    2013.11
# 3  Zuschuss Donatelli  사무용품   바인더   22.720   4  0.2    7.3840    2012.08
# 4       Eric Hoffmann  사무용품   바인더   11.648   2  0.2    4.2224    2014.01
#
#   FirstOrder
# 0    2012.06
# 1    2012.04
# 2    2012.06
# 3    2012.08
# 4    2012.11

# %%
## 주기별 구매 User 계산
co1 = new_df.groupby(['FirstOrder', 'OrderCycle'])['이름'].nunique()
co1 = co1.reset_index()
co1.rename({'이름': 'TotalUsers'}, axis = 1, inplace = True)
co1
# Out:
#     FirstOrder OrderCycle  TotalUsers
# 0      2012.01    2012.01           9
# 1      2012.01    2012.02           2
# 2      2012.01    2012.05           1
# 3      2012.01    2012.08           1
# 4      2012.01    2012.09           1
# ..         ...        ...         ...
# 545    2015.03    2015.06           1
# 546    2015.03    2015.08           1
# 547    2015.08    2015.08           1
# 548    2015.08    2015.11           1
# 549    2015.12    2015.12           1
#
# [550 rows x 3 columns]

# %%
## 주기별 구매 금액 계산
co2 = new_df.groupby(['FirstOrder', 'OrderCycle'])['매출'].sum()
co2 = co2.reset_index()
co2.rename({'TotalCharges': 'PurchaseAmnt'}, axis = 1, inplace = True)
co2
# Out:
#     FirstOrder OrderCycle        매출
# 0      2012.01    2012.01   730.994
# 1      2012.01    2012.02    26.098
# 2      2012.01    2012.05    11.880
# 3      2012.01    2012.08    49.568
# 4      2012.01    2012.09   304.990
# ..         ...        ...       ...
# 545    2015.03    2015.06   895.920
# 546    2015.03    2015.08   895.920
# 547    2015.08    2015.08    31.128
# 548    2015.08    2015.11    11.673
# 549    2015.12    2015.12  1889.990
#
# [550 rows x 3 columns]

# %%
## 데이터의 병합
co = co1.merge(co2, on = ['FirstOrder', 'OrderCycle'])
co.head()
# Out:
#   FirstOrder OrderCycle  TotalUsers       매출
# 0    2012.01    2012.01           9  730.994
# 1    2012.01    2012.02           2   26.098
# 2    2012.01    2012.05           1   11.880
# 3    2012.01    2012.08           1   49.568
# 4    2012.01    2012.09           1  304.990

# %%
pip install ipypb

# %%
from ipypb import ipb
temp = []

for i in ipb(range(co.shape[0])):
    f_first_order = pd.to_datetime(co.FirstOrder[i]).to_period('M')
    f_order_cycle = pd.to_datetime(co.OrderCycle[i]).to_period('M')

    month_diff = (f_order_cycle - f_first_order).n

    temp.append(month_diff)
co['CohortPeriod'] = temp
# Out:
#  [████████████████████████████████████████████████████████████] 550/550 [00:00<00:00, 0.00s/it]

# %%
co.head()
# Out:
#   FirstOrder OrderCycle  TotalUsers       매출  CohortPeriod
# 0    2012.01    2012.01           9  730.994             0
# 1    2012.01    2012.02           2   26.098             1
# 2    2012.01    2012.05           1   11.880             4
# 3    2012.01    2012.08           1   49.568             7
# 4    2012.01    2012.09           1  304.990             8

# %%
## 첫 번째. 재방문율 계산을 위한 Pandas Unstack 활용
co_retention = co.set_index(['FirstOrder', 'CohortPeriod'])
co_retention = co_retention.TotalUsers.unstack(1)
retention = co_retention.div(co_retention[0],axis = 0)
retention
# Out:
# CohortPeriod   0         1         2         3         4         5         6   \
# FirstOrder
# 2012.01       1.0  0.222222       NaN       NaN  0.111111       NaN       NaN
# 2012.02       1.0  0.333333       NaN  0.111111  0.111111  0.111111       NaN
# 2012.03       1.0       NaN       NaN       NaN  0.076923  0.153846  0.153846
# 2012.04       1.0  0.076923  0.153846  0.076923  0.076923       NaN  0.153846
# 2012.05       1.0  0.076923  0.076923       NaN  0.153846       NaN  0.076923
# 2012.06       1.0  0.142857       NaN  0.071429  0.142857  0.214286  0.071429
# 2012.07       1.0  0.142857  0.214286  0.071429  0.142857  0.142857       NaN
# 2012.08       1.0       NaN  0.076923  0.153846  0.076923  0.076923       NaN
# 2012.09       1.0  0.052632  0.157895  0.052632       NaN  0.052632  0.105263
# 2012.10       1.0  0.083333  0.083333       NaN       NaN       NaN  0.166667
# 2012.11       1.0       NaN       NaN  0.071429  0.071429  0.214286  0.142857
# ...

# %%
## 두 번째. 구매 규모 형태 치환을 위한 Pandas Unstack 활용
co_purchase = co.set_index(['FirstOrder', 'CohortPeriod'])
co_purchase = co_purchase['매출'].unstack(1)
co_purchase
# Out:
# CohortPeriod        0         1         2         3         4         5   \
# FirstOrder
# 2012.01        730.994    26.098       NaN       NaN    11.880       NaN
# 2012.02        251.624   187.266       NaN    91.680    31.086    41.904
# 2012.03       1112.123       NaN       NaN       NaN   196.704   514.521
# 2012.04        890.928    17.960    64.140    15.600    77.400       NaN
# 2012.05       3786.784    68.480    27.360       NaN   143.268       NaN
# 2012.06       4016.027  2188.848       NaN    43.176   129.920    26.960
# 2012.07        433.290    27.384    32.272     1.788    36.522    19.388
# 2012.08       3428.142       NaN     8.682  3075.812  1655.955    13.168
# 2012.09        353.118    18.264   342.057    46.720       NaN    10.896
# 2012.10        219.582     9.980    46.320       NaN       NaN       NaN
# 2012.11       2235.560       NaN       NaN     2.934  6354.950  3834.870
# 2012.12       1760.625       NaN    17.238       NaN     6.900       NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

## 재방문율 시각화 진행
plt.rcParams['figure.figsize'] = (30, 15)
sns.heatmap(retention, annot = True, fmt = '.0%')
# Out:
# <Axes: xlabel='CohortPeriod', ylabel='FirstOrder'>

# %%
## 구매 규모 시각화
plt.rcParams['figure.figsize'] = (30, 15)
sns.heatmap(co_purchase, annot = True
           # , fmt = '.0%'
           )

plt.yticks(rotation = 360);
